# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("rent.csv")
df
# Out:
#                post_id      date  year       nhood        city   county  \
# 0       pre2013_134138  20050111  2005     alameda     alameda  alameda
# 1       pre2013_135669  20050126  2005     alameda     alameda  alameda
# 2       pre2013_127127  20041017  2004     alameda     alameda  alameda
# 3        pre2013_68671  20120601  2012     alameda     alameda  alameda
# 4       pre2013_127580  20041021  2004     alameda     alameda  alameda
# ...                ...       ...   ...         ...         ...      ...
# 200791  pre2013_126116  20040925  2004  yountville  yountville     napa
# 200792  pre2013_162529  20060221  2006  yountville  yountville     napa
# 200793   pre2013_65092  20120402  2012  yountville  yountville     napa
# 200794   pre2013_57294  20120307  2012  yountville  yountville     napa
# 200795   pre2013_78888  20080416  2008  yountville  yountville     napa
#
#         price  beds  baths    sqft  room_in_apt address  lat  lon  \
# 0        1250   2.0    2.0     NaN            0     NaN  NaN  NaN
# 1        1295   2.0    NaN     NaN            0     NaN  NaN  NaN
# 2        1100   2.0    NaN     NaN            0     NaN  NaN  NaN
# 3        1425   1.0    NaN   735.0            0     NaN  NaN  NaN
# 4         890   1.0    NaN     NaN            0     NaN  NaN  NaN
# ...       ...   ...    ...     ...          ...     ...  ...  ...
# 200791   1850   2.0    NaN     NaN            0     NaN  NaN  NaN
# 200792   1950   2.0    NaN     NaN            0     NaN  NaN  NaN
# 200793   2600   2.0    2.0  1300.0            0     NaN  NaN  NaN
# 200794   1900   2.0    NaN  1000.0            0     NaN  NaN  NaN
# 200795   1650   2.0    NaN     NaN            0     NaN  NaN  NaN
#
#                                                     title descr details
# 0       $1250 / 2br - 2BR/2BA   1145 ALAMEDA DE LAS PU...   NaN     NaN
# 1       $1295 / 2br - Walk the Beach! 1 FREE MONTH + $...   NaN     NaN
# 2                                   $1100 / 2br - cottage   NaN     NaN
# 3       $1425 / 1br - 735ft² - BEST LOCATION SOUTHSHOR...   NaN     NaN
# 4       $890 / 1br - Classy "Painted Lady" VICTORIAN -...   NaN     NaN
# ...                                                   ...   ...     ...
# 200791  $1850 / 2br - Yountville - LARGE townhouse in ...   NaN     NaN
# 200792                    $1950 / 2br - Yountville duplex   NaN     NaN
# 200793  $2600 / 2br - 1300ft² - Fully furnished two be...   NaN     NaN
# 200794  $1900 / 2br - 1000ft² - Charming Old Town Youn...   NaN     NaN
# 200795  $1650 / 2br - Yountville cottage home with pool -   NaN     NaN
#
# [200796 rows x 17 columns]

# %%
df = df.dropna()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from plotnine import *
from sklearn.feature_extraction.text import CountVectorizer

# modeling imports
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV # Linear Regression Model
from sklearn.preprocessing import StandardScaler,OneHotEncoder, PolynomialFeatures, SplineTransformer #Z-score variables, Polynomial
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error #model evaluation
from sklearn.model_selection import train_test_split

# pipeline imports
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import make_column_transformer

# %matplotlib inline

# %%
df
# Out:
#            post_id      date  year                   nhood      city  \
# 515     4710888130  20141012  2014                 alameda   alameda
# 714     4988581576  20150421  2015                 alameda   alameda
# 959     4988561264  20150421  2015                 alameda   alameda
# 1034    4855533017  20150120  2015                 alameda   alameda
# 1118    4631188738  20140824  2014                 alameda   alameda
# ...            ...       ...   ...                     ...       ...
# 200285  5943507344  20170112  2017  willow glen / cambrian  cambrian
# 200337  6480256605  20180201  2018  willow glen / cambrian  cambrian
# 200346  5955718625  20170112  2017  willow glen / cambrian  cambrian
# 200378  4834909852  20150106  2015  willow glen / cambrian  cambrian
# 200537  4710901716  20141012  2014                woodside  woodside
#
#              county  price  beds  baths    sqft  room_in_apt address  \
# 515         alameda   2250   2.0    1.0  1080.0            0     659
# 714         alameda   2650   2.0    1.0   950.0            0     497
# 959         alameda   1950   2.0    1.0   800.0            0    2105
# 1034        alameda   2650   2.0    1.0   950.0            0     497
# 1118        alameda   3295   4.0    1.0  1716.0            0    1116
# ...             ...    ...   ...    ...     ...          ...     ...
# 200285  santa clara   2725   2.0    2.0  1182.0            0    2498
# 200337  santa clara   4300   4.0    2.5  1691.0            0    2795
# 200346  santa clara   2990   3.0    2.0  1360.0            0    2638
# 200378  santa clara   1825   1.0    1.0   720.0            0    1804
# 200537    san mateo   9950   4.0    3.0  4000.0            0    1458
#
#               lat         lon  \
# 515     37.772835 -122.248585
# 714     37.758922 -122.263314
# 959     37.773228 -122.266480
# 1034    37.758922 -122.263314
# 1118    37.732229 -122.234879
# ...           ...         ...
# 200285  37.290680 -121.874400
# 200337  37.329220 -121.895800
# 200346  37.310240 -121.897500
# 200378  37.307320 -121.913500
# 200537  37.416870 -122.252100
#
#                                                     title  \
# 515                     2br Victortian Duplex Garden Apt.
# 714     Upgraded 2B w/ Pool View, Short Walk to School...
# 959       BRAND NEW REMODELED 2-BR / 1-BA END-UNIT, SUNNY
# 1034    Fully Upgraded and lovely Unit Close to School...
# 1118    Originally 4-bedroom Townhouse in Bay Farm Island
# ...                                                   ...
# 200285  Fabulous Newer w/  Pd. Utilities | 4 wk Free  ...
# 200337  For Rent - 4 bed 2.5 bathrooms - Great school ...
# 200346                    short term rental $2990/monthly
# 200378  Spacious 1 Bed, Everything is New, Granite, Mi...
# 200537             Woodside Mid Century Modern 4+4+Office
#
#                                                     descr  \
# 515     This 1903 "Workingman's Victorian" on a quiet ...
# 714     Enjoy and experience the relaxing atmosphere o...
# 959     Be the first to live in this freshly remodeled...
# 1034    Enjoy and experience the relaxing atmosphere o...
# 1118    3546 Magnolia Dr., Alameda, CAA peaceful and c...
# ...                                                   ...
# 200285  Willow Glen This is a GREAT time of year to ge...
# 200337  Apartment walking distance to VTA Light Rail, ...
# 200346  near downtown Willow Glen, 3 bedrooms, 1 & 1/2...
# 200378  Willow Glen Apartments996 Meridian AveSan Jose...
# 200537  Come home to peaceful Woodside, the private la...
#
#                                                   details
# 515     2BR / 1Ba 1080ft2 apartment  date="2014-11-02"...
# 714     2BR / 1Ba 950ft2 apartment  date="2015-04-20" ...
# 959     2BR / 1Ba 800ft2 apartment  date="2015-04-21" ...
# 1034    2BR / 1Ba 950ft2 apartment  date="2015-01-20" ...
# 1118    3BR / 2.5Ba 1716ft2 apartment  date="2014-09-0...
# ...                                                   ...
# 200285  2BR / 2Ba1182ft2 data-date="2017-01-01" data-t...
# 200337  <p class="attrgroup">"shared-line-bubble">1BR ...
# 200346  3BR / 1Ba1360ft2 data-date="2017-09-01" data-t...
# 200378  1BR / 1Ba 720ft2 apartment  date="2015-01-06" ...
# 200537  4BR / 4Ba 4000ft2 house  date="2015-07-15" tod...
#
# [1534 rows x 17 columns]

# %%
predictors = ['date', 'year', 'nhood','city','county', 'beds','baths','sqft','room_in_apt','address','lat','lon','title','descr']
y = df['price']
X = df[predictors]

# %%
df['title_length'] = df['title'].apply(len)
df['descr_length'] = df['descr'].apply(len)

# %%
df
# Out:
#            post_id      date  year                   nhood      city  \
# 515     4710888130  20141012  2014                 alameda   alameda
# 714     4988581576  20150421  2015                 alameda   alameda
# 959     4988561264  20150421  2015                 alameda   alameda
# 1034    4855533017  20150120  2015                 alameda   alameda
# 1118    4631188738  20140824  2014                 alameda   alameda
# ...            ...       ...   ...                     ...       ...
# 200285  5943507344  20170112  2017  willow glen / cambrian  cambrian
# 200337  6480256605  20180201  2018  willow glen / cambrian  cambrian
# 200346  5955718625  20170112  2017  willow glen / cambrian  cambrian
# 200378  4834909852  20150106  2015  willow glen / cambrian  cambrian
# 200537  4710901716  20141012  2014                woodside  woodside
#
#              county  price  beds  baths    sqft  room_in_apt address  \
# 515         alameda   2250   2.0    1.0  1080.0            0     659
# 714         alameda   2650   2.0    1.0   950.0            0     497
# 959         alameda   1950   2.0    1.0   800.0            0    2105
# 1034        alameda   2650   2.0    1.0   950.0            0     497
# 1118        alameda   3295   4.0    1.0  1716.0            0    1116
# ...             ...    ...   ...    ...     ...          ...     ...
# 200285  santa clara   2725   2.0    2.0  1182.0            0    2498
# 200337  santa clara   4300   4.0    2.5  1691.0            0    2795
# 200346  santa clara   2990   3.0    2.0  1360.0            0    2638
# 200378  santa clara   1825   1.0    1.0   720.0            0    1804
# 200537    san mateo   9950   4.0    3.0  4000.0            0    1458
#
#               lat         lon  \
# 515     37.772835 -122.248585
# 714     37.758922 -122.263314
# 959     37.773228 -122.266480
# 1034    37.758922 -122.263314
# 1118    37.732229 -122.234879
# ...           ...         ...
# 200285  37.290680 -121.874400
# 200337  37.329220 -121.895800
# 200346  37.310240 -121.897500
# 200378  37.307320 -121.913500
# 200537  37.416870 -122.252100
#
#                                                     title  \
# 515                     2br Victortian Duplex Garden Apt.
# 714     Upgraded 2B w/ Pool View, Short Walk to School...
# 959       BRAND NEW REMODELED 2-BR / 1-BA END-UNIT, SUNNY
# 1034    Fully Upgraded and lovely Unit Close to School...
# 1118    Originally 4-bedroom Townhouse in Bay Farm Island
# ...                                                   ...
# 200285  Fabulous Newer w/  Pd. Utilities | 4 wk Free  ...
# 200337  For Rent - 4 bed 2.5 bathrooms - Great school ...
# 200346                    short term rental $2990/monthly
# 200378  Spacious 1 Bed, Everything is New, Granite, Mi...
# 200537             Woodside Mid Century Modern 4+4+Office
#
#                                                     descr  \
# 515     This 1903 "Workingman's Victorian" on a quiet ...
# 714     Enjoy and experience the relaxing atmosphere o...
# 959     Be the first to live in this freshly remodeled...
# 1034    Enjoy and experience the relaxing atmosphere o...
# 1118    3546 Magnolia Dr., Alameda, CAA peaceful and c...
# ...                                                   ...
# 200285  Willow Glen This is a GREAT time of year to ge...
# 200337  Apartment walking distance to VTA Light Rail, ...
# 200346  near downtown Willow Glen, 3 bedrooms, 1 & 1/2...
# 200378  Willow Glen Apartments996 Meridian AveSan Jose...
# 200537  Come home to peaceful Woodside, the private la...
#
#                                                   details  title_length  \
# 515     2BR / 1Ba 1080ft2 apartment  date="2014-11-02"...            33
# 714     2BR / 1Ba 950ft2 apartment  date="2015-04-20" ...            62
# 959     2BR / 1Ba 800ft2 apartment  date="2015-04-21" ...            47
# 1034    2BR / 1Ba 950ft2 apartment  date="2015-01-20" ...            62
# 1118    3BR / 2.5Ba 1716ft2 apartment  date="2014-09-0...            49
# ...                                                   ...           ...
# 200285  2BR / 2Ba1182ft2 data-date="2017-01-01" data-t...            69
# 200337  <p class="attrgroup">"shared-line-bubble">1BR ...            54
# 200346  3BR / 1Ba1360ft2 data-date="2017-09-01" data-t...            31
# 200378  1BR / 1Ba 720ft2 apartment  date="2015-01-06" ...            65
# 200537  4BR / 4Ba 4000ft2 house  date="2015-07-15" tod...            38
#
#         descr_length
# 515              801
# 714             1610
# 959              764
# 1034            1769
# 1118            1746
# ...              ...
# 200285          1902
# 200337           722
# 200346           109
# 200378          1352
# 200537          1734
#
# [1534 rows x 19 columns]

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ryanj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ryanj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def sentenceSegment(text):
    sentences = []
    start = 0

    for i in range(len(text)):
        if text[i] == '.' or text[i] == '!' or text[i] == '?':
            sentences.append(text[start:i+1].strip())
            start = i + 1

    return sentences

# %%
import string
def remove_punctuation(input_string):
    # Define a string of punctuation marks and symbols
    punctuations = string.punctuation
    
    # Remove the punctuation marks and symbols from the input string
    output_string = "".join(char for char in input_string if char not in punctuations)
    
    return output_string

# %%
def convertToLower(s):
  return s.lower()

# %%
def tokenize(s):
  words = [] #token words should be stored here
  i = 0
  word = ""
  while(i <len(s)):
    if (s[i] != " "):
      word = word+s[i]
    else:
        words.append(word)
        word = ""
    
    i = i + 1
  words.append(word)
  return words

# %%
def cleanText(text):
    puncRemovedText = remove_punctuation(text)
    lowerText = convertToLower(puncRemovedText)
    tokenizedText = tokenize(lowerText)
    stop_words = set(stopwords.words("english"))
    filtered_tokens = [token for token in tokenizedText if token.lower() not in stop_words]
    return filtered_tokens

# %%
df['cleaned_title'] = df['title'].apply(cleanText)
df
# Out:
#            post_id      date  year                   nhood      city  \
# 515     4710888130  20141012  2014                 alameda   alameda
# 714     4988581576  20150421  2015                 alameda   alameda
# 959     4988561264  20150421  2015                 alameda   alameda
# 1034    4855533017  20150120  2015                 alameda   alameda
# 1118    4631188738  20140824  2014                 alameda   alameda
# ...            ...       ...   ...                     ...       ...
# 200285  5943507344  20170112  2017  willow glen / cambrian  cambrian
# 200337  6480256605  20180201  2018  willow glen / cambrian  cambrian
# 200346  5955718625  20170112  2017  willow glen / cambrian  cambrian
# 200378  4834909852  20150106  2015  willow glen / cambrian  cambrian
# 200537  4710901716  20141012  2014                woodside  woodside
#
#              county  price  beds  baths    sqft  room_in_apt address  \
# 515         alameda   2250   2.0    1.0  1080.0            0     659
# 714         alameda   2650   2.0    1.0   950.0            0     497
# 959         alameda   1950   2.0    1.0   800.0            0    2105
# 1034        alameda   2650   2.0    1.0   950.0            0     497
# 1118        alameda   3295   4.0    1.0  1716.0            0    1116
# ...             ...    ...   ...    ...     ...          ...     ...
# 200285  santa clara   2725   2.0    2.0  1182.0            0    2498
# 200337  santa clara   4300   4.0    2.5  1691.0            0    2795
# 200346  santa clara   2990   3.0    2.0  1360.0            0    2638
# 200378  santa clara   1825   1.0    1.0   720.0            0    1804
# 200537    san mateo   9950   4.0    3.0  4000.0            0    1458
#
#               lat         lon  \
# 515     37.772835 -122.248585
# 714     37.758922 -122.263314
# 959     37.773228 -122.266480
# 1034    37.758922 -122.263314
# 1118    37.732229 -122.234879
# ...           ...         ...
# 200285  37.290680 -121.874400
# 200337  37.329220 -121.895800
# 200346  37.310240 -121.897500
# 200378  37.307320 -121.913500
# 200537  37.416870 -122.252100
#
#                                                     title  \
# 515                     2br Victortian Duplex Garden Apt.
# 714     Upgraded 2B w/ Pool View, Short Walk to School...
# 959       BRAND NEW REMODELED 2-BR / 1-BA END-UNIT, SUNNY
# 1034    Fully Upgraded and lovely Unit Close to School...
# 1118    Originally 4-bedroom Townhouse in Bay Farm Island
# ...                                                   ...
# 200285  Fabulous Newer w/  Pd. Utilities | 4 wk Free  ...
# 200337  For Rent - 4 bed 2.5 bathrooms - Great school ...
# 200346                    short term rental $2990/monthly
# 200378  Spacious 1 Bed, Everything is New, Granite, Mi...
# 200537             Woodside Mid Century Modern 4+4+Office
#
#                                                     descr  \
# 515     This 1903 "Workingman's Victorian" on a quiet ...
# 714     Enjoy and experience the relaxing atmosphere o...
# 959     Be the first to live in this freshly remodeled...
# 1034    Enjoy and experience the relaxing atmosphere o...
# 1118    3546 Magnolia Dr., Alameda, CAA peaceful and c...
# ...                                                   ...
# 200285  Willow Glen This is a GREAT time of year to ge...
# 200337  Apartment walking distance to VTA Light Rail, ...
# 200346  near downtown Willow Glen, 3 bedrooms, 1 & 1/2...
# 200378  Willow Glen Apartments996 Meridian AveSan Jose...
# 200537  Come home to peaceful Woodside, the private la...
#
#                                                   details  title_length  \
# 515     2BR / 1Ba 1080ft2 apartment  date="2014-11-02"...            33
# 714     2BR / 1Ba 950ft2 apartment  date="2015-04-20" ...            62
# 959     2BR / 1Ba 800ft2 apartment  date="2015-04-21" ...            47
# 1034    2BR / 1Ba 950ft2 apartment  date="2015-01-20" ...            62
# 1118    3BR / 2.5Ba 1716ft2 apartment  date="2014-09-0...            49
# ...                                                   ...           ...
# 200285  2BR / 2Ba1182ft2 data-date="2017-01-01" data-t...            69
# 200337  <p class="attrgroup">"shared-line-bubble">1BR ...            54
# 200346  3BR / 1Ba1360ft2 data-date="2017-09-01" data-t...            31
# 200378  1BR / 1Ba 720ft2 apartment  date="2015-01-06" ...            65
# 200537  4BR / 4Ba 4000ft2 house  date="2015-07-15" tod...            38
#
#         descr_length                                      cleaned_title
# 515              801             [2br, victortian, duplex, garden, apt]
# 714             1610  [upgraded, 2b, w, pool, view, short, walk, sch...
# 959              764  [brand, new, remodeled, 2br, , 1ba, endunit, s...
# 1034            1769  [fully, upgraded, lovely, unit, close, school,...
# 1118            1746  [originally, 4bedroom, townhouse, bay, farm, i...
# ...              ...                                                ...
# 200285          1902  [fabulous, newer, w, , pd, utilities, , 4, wk,...
# 200337           722  [rent, , 4, bed, 25, bathrooms, , great, schoo...
# 200346           109                 [short, term, rental, 2990monthly]
# 200378          1352  [spacious, 1, bed, everything, new, granite, m...
# 200537          1734         [woodside, mid, century, modern, 44office]
#
# [1534 rows x 20 columns]

# %%
X = df['cleaned_title']

# %%
cv = CountVectorizer()
bow_transformer = CountVectorizer(analyzer = cleanText).fit(df['title'])
len(bow_transformer.vocabulary_)
title_bow = bow_transformer.transform(df['title'])
print("shape of sparse matrix: ", title_bow.shape)
title_bow.nnz
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer().fit(title_bow)
title_tfidf = tfidf_transformer.transform(title_bow)
print(title_tfidf)
# Out:
# shape of sparse matrix:  (1534, 2143)
#   (0, 1998)	0.6155738397694961
#   (0, 1039)	0.42244877675930154
#   (0, 883)	0.4059547562342764
#   (0, 457)	0.3429970553393025
#   (0, 196)	0.40019949365953117
#   (1, 2025)	0.28453041963664694
#   (1, 2020)	0.27322088142504564
#   (1, 2000)	0.24651522661787623
#   (1, 1972)	0.3547210883099734
#   (1, 1762)	0.3609152300914337
#   (1, 1758)	0.3139709848675096
#   (1, 1726)	0.2963278442346204
#   (1, 1573)	0.3083677020509964
#   (1, 431)	0.21012192879458236
#   (1, 165)	0.4493398983625965
#   (2, 1875)	0.3581732337134398
#   (2, 1641)	0.26048107337344995
#   (2, 1437)	0.26263991703861095
#   (2, 914)	0.530718221922502
#   (2, 604)	0.36421506108671786
#   (2, 196)	0.3450327969895592
#   (2, 90)	0.4063034409818151
#   (2, 0)	0.19088546327140585
#   (3, 1972)	0.37961192958284373
#   (3, 1961)	0.270110021812436
#   :	:
#   (1530, 1647)	0.23240917090853994
#   (1530, 1080)	0.24717569987527843
#   (1530, 856)	0.3758967080862081
#   (1530, 544)	0.26260253502203607
#   (1530, 516)	0.4649532340559151
#   (1530, 280)	0.3071307980068896
#   (1530, 139)	0.3574158091697438
#   (1530, 0)	0.3532001456440715
#   (1531, 1895)	0.46193029310128814
#   (1531, 1762)	0.46193029310128814
#   (1531, 1650)	0.49243929337154296
#   (1531, 162)	0.5751037740916429
#   (1532, 1806)	0.2310421038712453
#   (1532, 1437)	0.24682866415959268
#   (1532, 1380)	0.47230888020081807
#   (1532, 1079)	0.37662011622592645
#   (1532, 934)	0.39374122208375867
#   (1532, 544)	0.26675695568823216
#   (1532, 158)	0.498768318385615
#   (1532, 3)	0.21404557394181079
#   (1533, 2093)	0.4826498909910386
#   (1533, 1391)	0.3037377706182753
#   (1533, 1368)	0.4570455282341745
#   (1533, 684)	0.4826498909910386
#   (1533, 287)	0.4826498909910386

# %%
LR = LinearRegression()
LR = LinearRegression().fit(title_tfidf, df['price'])
all_pred = LR.predict(title_tfidf)
all_pred
# Out:
# array([2249.95218192, 2649.96280146, 1950.00857081, ..., 2989.97821886,
#        1825.00718105, 9950.00379131])

# %%
contin = ['year', 'beds', 'baths','sqft','lat','lon','title_length','descr_length']
X = df.drop(['post_id', 'cleaned_title','details','price','date','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
nlp = df[['title', 'descr']]

# %%
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(), categorical),
    remainder = "passthrough"
)

# %%
scoresR2 = []

# %%
#without year
contin = ['beds', 'baths','sqft','lat','lon','title_length','descr_length']
X = df.drop(['year','post_id', 'cleaned_title','details','price','date','title','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 101)
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(handle_unknown='ignore'), categorical),
    remainder = "passthrough"
)
LR = LinearRegression()
pipeline = Pipeline([
    ('pre',pre),
    ('LR', LinearRegression())
])
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)
r2 = r2_score(y_test, predictions)
print("R2: ", r2)
scoresR2.append(r2)
# Out:
# R2:  0.6028888167928139

# %%
#without beds
contin = ['year', 'baths','sqft','lat','lon','title_length','descr_length']
X = df.drop(['beds','post_id', 'cleaned_title','details','price','date','title','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 101)
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(handle_unknown='ignore'), categorical),
    remainder = "passthrough"
)
LR = LinearRegression()
pipeline = Pipeline([
    ('pre',pre),
    ('LR', LinearRegression())
])
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)
r2 = r2_score(y_test, predictions)
print("R2: ", r2)
scoresR2.append(r2)
# Out:
# R2:  0.6034795639627281

# %%
#without baths
contin = ['year', 'beds','sqft','lat','lon','title_length','descr_length']
X = df.drop(['baths','post_id', 'cleaned_title','details','price','date','title','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 101)
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(handle_unknown='ignore'), categorical),
    remainder = "passthrough"
)
LR = LinearRegression()
pipeline = Pipeline([
    ('pre',pre),
    ('LR', LinearRegression())
])
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)
r2 = r2_score(y_test, predictions)
print("R2: ", r2)
scoresR2.append(r2)
# Out:
# R2:  0.6055969158282273

# %%
#without sqft
contin = ['year', 'baths','beds','lat','lon','title_length','descr_length']
X = df.drop(['sqft','post_id', 'cleaned_title','details','price','date','title','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 101)
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(handle_unknown='ignore'), categorical),
    remainder = "passthrough"
)
LR = LinearRegression()
pipeline = Pipeline([
    ('pre',pre),
    ('LR', LinearRegression())
])
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)
r2 = r2_score(y_test, predictions)
print("R2: ", r2)
scoresR2.append(r2)
# Out:
# R2:  0.3168372395209772

# %%
#without lat
contin = ['year', 'baths','sqft','beds','lon','title_length','descr_length']
X = df.drop(['lat','post_id', 'cleaned_title','details','price','date','title','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 101)
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(handle_unknown='ignore'), categorical),
    remainder = "passthrough"
)
LR = LinearRegression()
pipeline = Pipeline([
    ('pre',pre),
    ('LR', LinearRegression())
])
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)
r2 = r2_score(y_test, predictions)
print("R2: ", r2)
scoresR2.append(r2)
# Out:
# R2:  0.5985197617463156

# %%
#without lon
contin = ['year', 'baths','sqft','lat','beds','title_length','descr_length']
X = df.drop(['lon','post_id', 'cleaned_title','details','price','date','title','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 101)
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(handle_unknown='ignore'), categorical),
    remainder = "passthrough"
)
LR = LinearRegression()
pipeline = Pipeline([
    ('pre',pre),
    ('LR', LinearRegression())
])
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)
r2 = r2_score(y_test, predictions)
print("R2: ", r2)
scoresR2.append(r2)
# Out:
# R2:  0.6011736201442686

# %%
#without title length
contin = ['year', 'baths','sqft','lat','lon','beds','descr_length']
X = df.drop(['title_length','post_id', 'cleaned_title','details','price','date','title','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 101)
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(handle_unknown='ignore'), categorical),
    remainder = "passthrough"
)
LR = LinearRegression()
pipeline = Pipeline([
    ('pre',pre),
    ('LR', LinearRegression())
])
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)
r2 = r2_score(y_test, predictions)
print("R2: ", r2)
scoresR2.append(r2)
# Out:
# R2:  0.6030774389801852

# %%
#without descr length
contin = ['year', 'baths','sqft','lat','lon','title_length','beds']
X = df.drop(['descr_length','post_id', 'cleaned_title','details','price','date','title','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 101)
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(handle_unknown='ignore'), categorical),
    remainder = "passthrough"
)
LR = LinearRegression()
pipeline = Pipeline([
    ('pre',pre),
    ('LR', LinearRegression())
])
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)
r2 = r2_score(y_test, predictions)
print("R2: ", r2)
scoresR2.append(r2)
# Out:
# R2:  0.6131724417637414

# %%
#without nhood
contin = ['year', 'baths','sqft','lat','lon','title_length','beds', 'title_length','descr_length']
X = df.drop(['nhood','post_id', 'cleaned_title','details','price','date','title','descr', 'address'], axis =1)
y = df['price']
categorical = ['city','county']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 101)
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(handle_unknown='ignore'), categorical),
    remainder = "passthrough"
)
LR = LinearRegression()
pipeline = Pipeline([
    ('pre',pre),
    ('LR', LinearRegression())
])
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)
r2 = r2_score(y_test, predictions)
print("R2: ", r2)
scoresR2.append(r2)
# Out:
# R2:  0.583198870890332

# %%
#without nhood
contin = ['year', 'baths','sqft','lat','lon','title_length','beds', 'title_length','descr_length']
X = df.drop(['city','post_id', 'cleaned_title','details','price','date','title','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','county']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 101)
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(handle_unknown='ignore'), categorical),
    remainder = "passthrough"
)
LR = LinearRegression()
pipeline = Pipeline([
    ('pre',pre),
    ('LR', LinearRegression())
])
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)
r2 = r2_score(y_test, predictions)
print("R2: ", r2)
scoresR2.append(r2)
# Out:
# R2:  0.6029072404329484

# %%
#without nhood
contin = ['year', 'baths','sqft','lat','lon','title_length','beds', 'title_length','descr_length']
X = df.drop(['county','post_id', 'cleaned_title','details','price','date','title','descr', 'address'], axis =1)
y = df['price']
categorical = ['city','nhood']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 101)
pre = make_column_transformer(
    (StandardScaler(), contin),
    (OneHotEncoder(handle_unknown='ignore'), categorical),
    remainder = "passthrough"
)
LR = LinearRegression()
pipeline = Pipeline([
    ('pre',pre),
    ('LR', LinearRegression())
])
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)
r2 = r2_score(y_test, predictions)
print("R2: ", r2)
scoresR2.append(r2)
# Out:
# R2:  0.6015910033569652

# %%
scoresR2
# Out:
# [0.6028888167928139,
#  0.6034795639627281,
#  0.6055969158282273,
#  0.3168372395209772,
#  0.5985197617463156,
#  0.6011736201442686,
#  0.6030774389801852,
#  0.6131724417637414,
#  0.583198870890332,
#  0.6029072404329484,
#  0.6015910033569652]

# %%
predictorsNames = ['year','beds', 'baths','sqft','latitude','longitude','title_length','descr_length', 'nhood','city','county']

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (15,5))
plt.bar(predictorsNames, scoresR2, width = 0.5)
plt.xlabel("Predictors")
plt.ylabel("R2")
plt.title("predictors vs R2 values once removed")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['descr'],df['price'], test_size = .2, random_state = 101)

# %%
from sklearn.pipeline import Pipeline

# %%
pipeline = Pipeline([
    ('bow', CountVectorizer(analyzer=cleanText)),
    ('tfidf', TfidfTransformer()),
    #('pre',pre),
    ('LR', LinearRegression())
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function cleanText at 0x000002B8E8A03F60>)),
#                 ('tfidf', TfidfTransformer()), ('LR', LinearRegression())])

# %%
predictions = pipeline.predict(X_test)

# %%
from sklearn import metrics

# %%
print("MSE: ", mean_squared_error(y_test, predictions))
print("MAE: ", mean_absolute_error(y_test, predictions))
print("RMSE: ", np.sqrt(metrics.mean_squared_error(y_test, predictions)))
print("R2: ", r2_score(y_test, predictions))
# Out:
# MSE:  4216446.843282215
# MAE:  1437.4431413243587
# RMSE:  2053.3988514855596
# R2:  -0.8889702826563561

# %%
metrics.explained_variance_score(y_test, predictions)
# Out:
# -0.8868591153709089

# %%
cv = CountVectorizer()
bow_transformer = CountVectorizer(analyzer = cleanText).fit(df['descr'])
len(bow_transformer.vocabulary_)
descr_bow = bow_transformer.transform(df['descr'])
print("shape of sparse matrix: ", descr_bow.shape)
descr_bow.nnz
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer().fit(descr_bow)
descr_tfidf = tfidf_transformer.transform(descr_bow)
print(descr_tfidf)
# Out:
# shape of sparse matrix:  (1534, 22532)
#   (0, 21995)	0.18973882765917632
#   (0, 21546)	0.07721828176163759
#   (0, 21337)	0.13021173167199127
#   (0, 21325)	0.16246607730093057
#   (0, 21310)	0.12169822178262726
#   (0, 21043)	0.0870844459859789
#   (0, 20906)	0.04985671296448144
#   (0, 20092)	0.0955168439699102
#   (0, 19860)	0.10530503052620623
#   (0, 19649)	0.13004472854706567
#   (0, 19540)	0.05618434352540058
#   (0, 19505)	0.10409382801094587
#   (0, 19404)	0.1130045420092474
#   (0, 19345)	0.0900332148620776
#   (0, 19109)	0.054365070255319455
#   (0, 18939)	0.12422494940194967
#   (0, 18629)	0.12512776624718286
#   (0, 18614)	0.10112615225869023
#   (0, 17913)	0.08474776616980098
#   (0, 17782)	0.15863932872743744
#   (0, 17663)	0.08158471957258233
#   (0, 17459)	0.06778351032213205
#   (0, 17364)	0.11475760385044312
#   (0, 17304)	0.09695219904370388
#   (0, 17095)	0.06398285184793381
#   :	:
#   (1533, 6053)	0.06399545095322416
#   (1533, 5917)	0.07928400476984132
#   (1533, 5803)	0.06538823652287826
#   (1533, 5608)	0.06443949844981975
#   (1533, 5570)	0.042415049594020725
#   (1533, 5550)	0.07832388331519241
#   (1533, 5544)	0.06554191910475358
#   (1533, 5441)	0.046656690841528445
#   (1533, 5364)	0.030122888267056305
#   (1533, 5323)	0.023535073571470715
#   (1533, 5058)	0.07578665251800816
#   (1533, 4962)	0.054539384159681514
#   (1533, 4680)	0.09107520633462533
#   (1533, 4468)	0.17414350633455605
#   (1533, 4198)	0.03573641617991616
#   (1533, 4167)	0.05926576824699538
#   (1533, 4098)	0.10072120982660757
#   (1533, 3945)	0.0854326560099904
#   (1533, 3204)	0.10072120982660757
#   (1533, 3188)	0.10636376015124249
#   (1533, 2285)	0.08717910065356518
#   (1533, 1646)	0.0464673513030848
#   (1533, 1029)	0.09361243713180957
#   (1533, 466)	0.0447865262542558
#   (1533, 0)	0.06106840202040805

# %%
print(descr_bow.max())
# Out:
# 8300

# %%
bow_transformer.get_feature_names_out()[8300]
# Out:
# 'desire'

# %%
# Implementation of matplotlib spy function 
import matplotlib.pyplot as plt 
import numpy as np 
  

fig = plt.figure(figsize = (10, 1))
plt.spy(descr_tfidf, precision = 0.3, markersize = 1) 

plt.show()

# %%
from sklearn.preprocessing import StandardScaler #Z-score variables

from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings('ignore')

# %%
contin = ['year', 'beds', 'baths','sqft','lat','lon','title_length','descr_length']
X = df.drop(['post_id', 'cleaned_title','details','title','price','date','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
feats = ['year', 'beds', 'baths','sqft','lat','lon','title_length','descr_length', 'nhood','city','county']

# %%
pre = make_column_transformer(
                            (StandardScaler(), contin),
                            remainder = "passthrough"
                            )

metrics = {"SSE": [], "sil": [], "k": []}

for i in range(2,20):
    km = KMeans(i)
    pipe = Pipeline([
        ("pre", pre),
        ("km", km)
    ])
    
    labels = pipe.fit_predict(X[contin])
    sil = silhouette_score(X[contin], labels)
    sse = pipe.named_steps["km"].inertia_

    metrics["SSE"].append(sse)
    metrics["sil"].append(sil)
    metrics["k"].append(i)

newdf = pd.DataFrame(metrics)

print(ggplot(newdf, aes(x = "k", y = "SSE")) +
  geom_line() + theme_minimal() +
    labs(x = "K", y = "Within Cluster SSE",
         title = "Within Cluster SSE for Different Ks"))

print(ggplot(newdf, aes(x = "k", y = "sil")) +
  geom_line() + theme_minimal() +
    labs(x = "K", y = "Mean Silhouette Score",
         title = "Silhouette Scores for Different Ks"))

# %%
pre = make_column_transformer(
                            (StandardScaler(), contin),
                            (OneHotEncoder(), categorical),
                            remainder = "passthrough"
                            )

km = KMeans(4)
pipe = Pipeline([
      ("pre", pre),
      ("km", km)
])
labels = pipe.fit_predict(X)

df["cluster"] = labels
print(ggplot(df, aes(x = "lat", y = "lon", color = "factor(cluster)")) +
      geom_point(aes(size='price')) +
      theme_minimal() + 
      scale_color_discrete(name = "Cluster") + 
      labs(x = "lat", 
           y = "lon",
           title = "4 Cluster Solution"))

# %%
contin = ['year', 'beds', 'baths','sqft','lat','title_length','descr_length']
X = df.drop(['post_id', 'cleaned_title','details','title','price','date','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
feats = ['year', 'beds', 'baths','sqft','lat','title_length','descr_length']

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()
pre = make_column_transformer(
                            (StandardScaler(), contin),
                            remainder = "passthrough"
                            )
pipe_pca = Pipeline([
    ("pre", pre),
    ("pca", pca)
])
pca_sub = df[feats]
pca_sub.dropna(inplace = True)
pca_sub.reset_index(inplace = True, drop = True)
pca_sub
# Out:
#       year  beds  baths    sqft        lat  title_length  descr_length
# 0     2014   2.0    1.0  1080.0  37.772835            33           801
# 1     2015   2.0    1.0   950.0  37.758922            62          1610
# 2     2015   2.0    1.0   800.0  37.773228            47           764
# 3     2015   2.0    1.0   950.0  37.758922            62          1769
# 4     2014   4.0    1.0  1716.0  37.732229            49          1746
# ...    ...   ...    ...     ...        ...           ...           ...
# 1529  2017   2.0    2.0  1182.0  37.290680            69          1902
# 1530  2018   4.0    2.5  1691.0  37.329220            54           722
# 1531  2017   3.0    2.0  1360.0  37.310240            31           109
# 1532  2015   1.0    1.0   720.0  37.307320            65          1352
# 1533  2014   4.0    3.0  4000.0  37.416870            38          1734
#
# [1534 rows x 7 columns]

# %%
pipe_pca.fit(pca_sub)
df_PCs = pd.DataFrame(pipe_pca.transform(pca_sub))
df_PCs.columns = ['PC'+ str(i+1) for i in range(7)]
df_PCs.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7
# 0 -0.319363 -1.062416  1.066811 -0.496875  0.058500  0.489813  0.014592
# 1 -0.579379  0.811457  0.327901  0.415480 -0.175220  0.507564 -0.323599
# 2 -0.680346 -0.611684  0.375680  0.277086 -0.329557  0.390552 -0.312867
# 3 -0.589805  0.954863  0.359749  0.397919 -0.040063  0.496138 -0.350906
# 4  1.221836  0.384217  0.775465 -0.301346  0.481617  1.548365 -0.745196

# %%
# scree/cumvar plot
pcaDF = pd.DataFrame({"expl_var" :
                      pipe_pca.named_steps["pca"].explained_variance_ratio_,
                      "pc": range(1,8),
                      "cum_var":
                      pipe_pca.named_steps["pca"].explained_variance_ratio_.cumsum()})

# scree
print(ggplot(pcaDF, aes(x = "pc", y = "expl_var")) + geom_line() + geom_point() +
 theme_minimal() + labs(x = "PCs", y = "Proportion of Explained Variance", title = "Scree Plot"))

# cumulative variance
pcaDF0 = pd.concat([pcaDF, pd.DataFrame({"pc": [0], "cum_var": [0]})]) # add 0,0 for reference

print(ggplot(pcaDF0, aes(x = "pc", y = "cum_var")) + geom_line() +
 geom_point() + geom_hline(yintercept = 0.95, color = "red", linetype = "dashed") +
 theme_minimal() + labs(x = "Number of PCs", y = "Cumulative Proportion of Explained Variance", title = "Cumulative Variance Plot"))

# %%
from sklearn.cluster import AgglomerativeClustering


from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

from sklearn.metrics import silhouette_score

from sklearn.compose import make_column_transformer
from sklearn.pipeline import Pipeline

# make sure you have these to make dendrograms!-------
import scipy.cluster.hierarchy as sch
from matplotlib import pyplot as plt

# %%
feats = ["PC" + str(i) for i in range(1,7)]
X = df_PCs[feats]
y = df["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2)

# %%
pre = make_column_transformer(
                            (StandardScaler(), feats),
                            remainder = "passthrough"
                            )
pca = PCA(n_components = 6)
pipe_lr = Pipeline([
    ("pre",pre),
    ("pca", pca),
    ("model", LinearRegression())
])
pipe_lr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   ['PC1', 'PC2', 'PC3', 'PC4',
#                                                    'PC5', 'PC6'])])),
#                 ('pca', PCA(n_components=6)), ('model', LinearRegression())])

# %%
y_pred_train = pipe_lr.predict(X_train)
y_pred_test  = pipe_lr.predict(X_test)

r2 = r2_score(y_train, y_pred_train)
print("Train R2: ", r2)
r2 = r2_score(y_test, y_pred_test)
print("Test R2: ", r2)
# Out:
# Train R2:  0.39960592320276056
# Test R2:  0.3366121743277277

# %%
contin = ['year', 'beds', 'baths','sqft','lat','lon','title_length','descr_length']
X = df.drop(['post_id', 'cleaned_title','details','title','price','date','descr', 'address'], axis =1)
y = df['price']
categorical = ['nhood','city','county']
feats = ['year', 'beds', 'baths','sqft','lat','lon','title_length','descr_length', 'nhood','city','county']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2)
pre = make_column_transformer(
                            (StandardScaler(), contin),
                            (OneHotEncoder(handle_unknown='ignore'), categorical),
                            remainder = "passthrough"
                            )
lr = LinearRegression()
pipe = Pipeline([
    ("pre", pre),
    ("lr", lr)
])
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   ['year', 'beds', 'baths',
#                                                    'sqft', 'lat', 'lon',
#                                                    'title_length',
#                                                    'descr_length']),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['nhood', 'city',
#                                                    'county'])])),
#                 ('lr', LinearRegression())])

# %%
y_pred_train = pipe.predict(X_train)
y_pred_test  = pipe.predict(X_test)

r2 = r2_score(y_train, y_pred_train)
print("Train R2: ", r2)
r2 = r2_score(y_test, y_pred_test)
print("Test R2: ", r2)
# Out:
# Train R2:  0.7491993317633855
# Test R2:  0.6605943132572667

# %%
heatmapVar = ['lat','lon','price']
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(16,6))
sns.heatmap(df[heatmapVar].corr()[['price']].sort_values(by='price',ascending=False),vmin=-1,vmax=1,annot=True,cmap='magma')
# Out:
# <Axes: >

# %%
print("avg price for room in apt")
print(df[df['room_in_apt'] == 1]['price'].mean())
print("avg price for not room in apt")
print(df[df['room_in_apt'] ==0]['price'].mean())
print("count for room in apt")
print(df[df['room_in_apt'] == 1]['price'].count())
print("count for not room in apt")
print(df[df['room_in_apt'] ==0]['price'].count())
# Out:
# avg price for room in apt
# 2768.4615384615386
# avg price for not room in apt
# 3037.554240631164
# count for room in apt
# 13
# count for not room in apt
# 1521

# %%
newdf = df[df['room_in_apt']==1]['price']

# %%
df.boxplot(column = 'price', by = 'room_in_apt')
# Out:
# <Axes: title={'center': 'price'}, xlabel='room_in_apt'>

# %%
df.boxplot(column = 'price', by = 'year')
# Out:
# <Axes: title={'center': 'price'}, xlabel='year'>

# %%
df['year'].value_counts()
# Out:
# year
# 2015    636
# 2014    626
# 2017    193
# 2018     75
# 2016      4
# Name: count, dtype: int64
